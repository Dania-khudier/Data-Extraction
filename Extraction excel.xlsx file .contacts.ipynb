# %%
import pandas as pd
from openpyxl import load_workbook
import os

# %%
filename = 'contacts.xlsx'
df = pd.read_excel(filename, engine='openpyxl')
print(df)
# Out:
#     الرقم Service Provider ID  \
# 0       1               04U01
# 1       2               04V12
# 2       3               04M03
# 3       4               04M04
# 4       5               04V19
# 5       6               04M06
# 6       7               04M07
# 7       8               04O01
# 8       9               04O02
# 9      10               04V01
# 10     11               04V02
# 11     12               04V03
# 12     13               04V04
# 13     14               04V05
# 14     15               04V06
# 15     16               04V07
# 16     17               04V08
# 17     18               04V09
# 18     19               04V10
# 19     20               04V11
# 20     21               04V13
# 21     22               04V14
# 22     23               04V15
# 23     24               04V16
# 24     25               04V17
# 25     26               04V18
# 26     27               04V19
# 27     28               04V20
# 28     29               04V21
# 29     30               04V22
#
#                             اسم البلدية/ مقدم الخدمة   المحافظة  \
# 0                             مصلحة مياه محافظة القدس  رام الله
# 1                                  مجلس قروي راس كركر  رام الله
# 2                                       بلدية بيتونيا  رام الله
# 3                              بلدية بني زيد الغربية   رام الله
# 4   jsc- Beit ligya- kharbatha al misbah مجلس خدما...  رام الله
# 5                                         بلدية نعلين  رام الله
# 6                                بلدية بيت عور التحتا  رام الله
# 7                           شركة قطرة للموارد المائية  رام الله
# 8                        اللجنة الشعبية مخيم دير عمار  رام الله
# 9                              مجلس قروي دير ابو مشعل  رام الله
# 10                                     مجلس قروي قبيا  رام الله
# 11                                     مجلس قروي شقبا  رام الله
# 12                                      مجلس قروي صفا  رام الله
# 13                                 مجلس قروي بيت سيرا  رام الله
# 14                                   مجلس قروي بيتللو  رام الله
# 15                                    مجلس قروي رنتيس  رام الله
# 16                                 مجلس قروي دير عمار  رام الله
# 17                                 مجلس قروي دير قديس  رام الله
# 18                                    مجلس قروي بلعين  رام الله
# 19                                    مجلس قروي عابود  رام الله
# 20                                    مجلس قروي جمالا  رام الله
# 21                                   مجلس قروي المدية  رام الله
# 22                                     مجلس قروي بدرس  رام الله
# 23                                  مجلس قروي الجانية  رام الله
# 24                                   مجلس قروي الطيره  رام الله
# 25                                    مجلس قروي شبتين  رام الله
# 26                           مجلس قروي خربثا بني حارث  رام الله
# 27                           مجلس قروي بيت عور الفوقا  رام الله
# 28                             مجلس قروي اللبن الغربي  رام الله
# 29                            مجلس قروي قراوة بني زيد  رام الله
#
#          اسم رئيس البلدية    رقم الفاكس               رقم الهاتف   \
# 0     م. عبد الخالق الكرمي   02-2954555                  22969191
# 1   راضي إسماعيل أبو فخيدة   02-2481615   02-2481615\n05952020400
# 2                 ضياء قرط   02-2900534                02-2900754
# 3       كايد شفيق الريماوي   02-2860112                02-2860110
# 4                اريج عاصي            \                         \
# 5             يوسف الخواجا          NaN                       NaN
# 6               حسين عليان          NaN                       NaN
# 7                      NaN          NaN                       NaN
# 8                      NaN          NaN                       NaN
# 9                      NaN          NaN                       NaN
# 10                     NaN          NaN                       NaN
# 11                     NaN          NaN                       NaN
# 12                     NaN          NaN                       NaN
# 13                     NaN          NaN                       NaN
# 14                     NaN          NaN                       NaN
# 15                     NaN          NaN                       NaN
# 16                     NaN          NaN                       NaN
# 17                     NaN          NaN                       NaN
# 18                     NaN          NaN                       NaN
# 19                     NaN          NaN                       NaN
# 20                     NaN          NaN                       NaN
# 21                     NaN          NaN                       NaN
# 22                     NaN          NaN                       NaN
# 23                     NaN          NaN                       NaN
# 24                     NaN          NaN                       NaN
# 25                     NaN          NaN                       NaN
# 26                     NaN          NaN                  22480803
# 27                     NaN          NaN                       NaN
# 28                     NaN          NaN                       NaN
# 29                     NaN          NaN                       NaN
#
#                                    ايميل البلدية   \
# 0                                             NaN
# 1                                             NaN
# 2                                info@beitunia.ps
# 3                                             NaN
# 4   manager@JSC-allegaa.ps\njsc.alleqaa@yahoo.com
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
#
#                           جهة التواصل                         رقم الموبايل   \
# 0                         عمر ابو قطيش                            599282600
# 1              بدر محمود عبد الله نوفل                            599666783
# 2   سامح بسام\nمدحت عابور\nسعد أبو زيد    594444861 \n594444801\n 599521333
# 3       نادي أحمد فايز الحج\nمحمد خطيب                597940417\n 599113373
# 4             رفيف حنايشة \nربا مفارجه  569920023\n 0599418185\n 0597389293
# 5                                ضياء                            0598645029
# 6                         مكافح سليمان                            598357400
# 7                       حسين الدواهيدي                           0597231132
# 8                           حسن الصافي                           0598342492
# 9                           صالح زهران                           0569720796
# 10                           بهاء عيسى                            562445101
# 11            ابراهيم المصري\nوفاء شلش               0599457341\n0594625645
# 12                          رائد منصور                           0562501124
# 13                        ابراهيم الحج                           0569336170
# 14                           فداء بزار                           0569717609
# 15                           مفيد بلوط                           0595049603
# 16                               تسنيم                            595436716
# 17                          صفاء قنديل                           0598125917
# 18                       غسان ابو رحمة                           0597511392
# 19                  ماهر فواضلة\nشيرين                0562262610\n599593416
# 20                    منال فوزي درامنه                           0597583528
# 21                         رانية حمودة                           0597417497
# 22                     عبد الناصر مرار                           0598535075
# 23                          عصام سمحان                           0593424201
# 24                        مكافح سليمان                           0598357400
# 25                     ابراهيم دار زيد                           0595437740
# 26                       م.عبد الجبار                            0599195495
# 27                          اشرف سمارة                           0594237336
# 28                           احمد صالح                           0598942967
# 29                           صادق عرار                            598862511
#
#          المسمى الوظيفي لجهة التواصل   \
# 0   رئيس قسم التخطيط والتحليل المالي
# 1                 محاسب و مساعد اداري
# 2   محاسب\nقسم المياه \nالمدير المالي
# 3                     رئيس قسم المياه
# 4           المدير التنفيذي\n\nمحاسبة
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
#
#                                    ايميل جهة التواصل  قديم /جديد
# 0                         omar@jwu.org\nkarmi@jwu.org       قديم
# 1                               bader.nofal@gmail.com       قديم
# 2   sasbuzaid@yahoo.com \nurban.paleng2008@yahoo.c...       قديم
# 3         n-remawe@yahoo.com \nnadialremawe@gmail.com       قديم
# 4   rafif.hanaishy@gmail.com\n\n robamafarjeh95@gm...       قديم
# 5                             dia2.nafi1988@gmail.com       جديد
# 6                            beiturtahta_lc@yahoo.com       جديد
# 7                                heldwahidi@rawabi.ps       جديد
# 8                         deerammarcamp2020@gmail.com       جديد
# 9   deirabumashaal@gmail.com\ndeirabumeshaalmajlis...       جديد
# 10                                qibya1953@gmail.com       جديد
# 11                                 shuqba25@yahoo.com       جديد
# 12                                  saffalc@yahoo.com       جديد
# 13                               beitsera56@yahoo.com       جديد
# 14                               fidabazzar@yahoo.com       جديد
# 15                                  mofedbt@gmail.com       جديد
# 16                            deirammar2017@gmail.com       جديد
# 17                          d.qaddiscouncil@gmail.com       جديد
# 18                              bilincl13@hotmail.com       جديد
# 19                           fawadleh.maher@yahoo.com       جديد
# 20                                mnal20050@gmail.com       جديد
# 21                                    rrsaz@yahoo.com       جديد
# 22                           budrus.council@gmail.com       جديد
# 23                 aljaniehvillagecouncil99@gmail.com       جديد
# 24                        altiracouncil2017@yahoo.com       جديد
# 25                                 shibteen@gmail.com       جديد
# 26                        majles_karbatha@hotmail.com       جديد
# 27                                aashraf@pcbs.gov.ps       جديد
# 28                               ahmadsmhan@yahoo.com       جديد
# 29                               sadeq_arar@yahoo.com       جديد

# %%
all_sheets = pd.read_excel(filename, sheet_name=None, engine='openpyxl')

all_texts = []

# %%
all_data = []

for sheet_name, df in all_sheets.items():
    print(f"محتوى الورقة: {sheet_name}")
# Out:
# محتوى الورقة: رام الله  (2)
# محتوى الورقة: القدس (2)

# %%
df_str = df.astype(str)

# %%
sheet_data = df_str.values.flatten().tolist()
all_data.extend(sheet_data)

# %%
for item in sheet_data:
        print(item)
# Out:
# 1
# 01J01
# مجلس خدمات شمال غرب القدس
# القدس
# يوسف الفقيه
# 02-2476234
# nan
# nan
# وجدان طه
# ديانا سمارة
# يعقوب فقيه
# حمزة الحلو
# 568289223
#  599071717
#  0568900975
#  0568300309
# العلاقات العامة
# مدير تنفيذي
# مسؤول فني
# مدير مالي
# wtaha@jwwd.ps
# dianasamra1@gmail.com
#  yfaqih@jwwd.ps
# hhello@jwwd.ps
# dsamara@jwwd.ps
# قديم
# nan
# 2
# 01M04
# بلدية السواحرة الشرقية
# القدس
# محمد موسى هلسة
# 02-2793122
# 02-2796463
# nan
# رهام عبيدات
# محمد عبد الرحمن
# 569126089
#  594774425
#
# محاسبة
# امين الصندوق
# ObedatReham@gmail.com
# M7Mad.Jafer22@gmail.com
#
# قديم
# nan
# 3
# 01M02
# بلدية العيزريه
# القدس
# محمد خليل أبو الريش
# 02-2796243
# 02-2799273
# info@aizariacouncil.org
# محمد قطميرة
# اياد خلف
# محمد يونس حمد
# 599115411
#  595542242
#  599255893
# رئيس قسم الهندسة
# محاسب
# المدير المالي
# qatmerah@yahoo.com
#  beckhamomr@hotmail.com
#  m.hamad@aizariacouncil.org
# قديم
# nan
# 4
# 01O01
# جمعية حياة ابوديس
# القدس
# زياد جفال
# 02-2794886
# 02-2796630
# nan
# ياسين عياد
# زياد جفال
#
# 569550834 569550831
# محاسب
# المدير المالي
# ayyadyasin@yahoo.com
# abudiswater@gmail.com
# قديم
# nan
# 5
# 01M01
# بلدية عناتا
# القدس
# طه نعمان
# 02-2355780
# 02-2355780
# nan
# احمد شيحة
# 597322867
# 022355780
# محاسب
# sheihaahmad8@gmail.com
# anata.municipality@gmail.com
#
# قديم
# nan
# 6
# 01M03
# بلدية الزعيم
# القدس
# ضرغام خليل
# nan
# nan
# nan
# محمد خليل
# 0522428011
# nan
# alzaayem-local@hotmail.com
# جديد
# nan
# 7
# 01M05
# بلدية الجيب
# القدس
# سامر عبد ربه
# nan
# nan
# nan
# ناصر شاهين
# 0599794973
# nan
# shahen_in200@yahoo.com
# aljeebcouncil@gmail.com
# جديد
# nan
# 8
# 01V01
# مجلس قروي الشيخ سعد
# القدس
# nan
# nan
# nan
# nan
# ابراهيم زعاترة
# 0569474407
# nan
# ibraheemrz_live2011@yahoo.com
# jamal-2054@hotmail.com
# جديد
# nan
# 9
# 01V02
# مجلس قروي عرب الجهالين
# القدس
# nan
# nan
# nan
# nan
# موسى جهالين
# 0597677158
# nan
# mousajahalen@gmail.com
# جديد
# nan
# 10
# 01V03
# مجلس قروي النبي صموئيل
# القدس
# nan
# nan
# nan
# nan
# محمد ابراهيم
# 0585885958
# nan
# ameerobeed2000@gmail.com
# جديد
# nan

# %%
output_dir = "extracted_images"
os.makedirs(output_dir, exist_ok=True)

wb = load_workbook(file_path)

img_count = 0
for sheet in wb.worksheets:
    for image in sheet._images:
        img_count += 1
        # Image Name and Extension
        ext = image.path.split('.')[-1] if image.path else "png"
        img_path = os.path.join(output_dir, f"image_{img_count}.{ext}")
        with open(img_path, "wb") as f:
            f.write(image._data())
        print(f"Extraction images from file {img_path}")

print(f"Extraction images from file {img_count}")
# Out:
# Extraction images from file 0
